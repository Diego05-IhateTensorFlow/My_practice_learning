# %% [markdown]
# Importamos las librerías (obviamente voy a ir añadiendo librerías en base vaya creciendo el código)

# %%
import os
import torch
import shutil
from torch import nn
from torch.nn import functional as f
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image, UnidentifiedImageError
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r'..\..\labels\labels.csv')
df
# Out:
#         filename label
# 0      10538.jpg   Cat
# 1      10539.jpg   Cat
# 2       1054.jpg   Cat
# 3      10540.jpg   Cat
# 4      10541.jpg   Cat
# ...          ...   ...
# 24760   8588.jpg   Dog
# 24761   9584.jpg   Dog
# 24762      1.jpg   Dog
# 24763   7968.jpg   Dog
# 24764   6604.jpg   Dog
#
# [24765 rows x 2 columns]

# %% [markdown]
# El dataset en sí mismo tiene "Filename collision" gracias a explorar las carpetas de imágenes, pero bueno ¿Qué quiere decir este término? Bueno, el término **Filename collision** refiere a que distintas imágenes tiene el mismo nombre, en este caso accederemos a la imagen "0.jpg", lo normal sería que solo diera un resultado, pero como podremos ver, no es el caso.

# %%
df[df['filename'] == '0.jpg']
# Out:
#       filename label
# 11803    0.jpg   Cat
# 12402    0.jpg   Dog

# %% [markdown]
# Como podemos ver, distintas imágenes tienen el mismo nombre '0.jpg', lo que puede causar problemas a la hora de entrenar el modelo, por ejemplo, si en el dataframe carga el archivo 0.jpg, Cat, pero el modelo (el DataLoader) carga 0.jpg, Dog, puede haber mala generalización, confusiones del modelo y resultados aleatorios.
#
# Para resolver esto, pensé en renombrar los archivos en una misma carpeta, pero no perdería los datos, porque me basaré en sus índices para crear sus nuevos nombres, sin perder la etiqueta que son.
#
# Primero realizamos el reseteo de índices del DataFrame con el parámetro drop en True para evitar que el índice que tiene, se convierta en una columna

# %%
df = df.reset_index(drop=True)

"""Una vez tenemos los índices, podemos crear los nombres, para esto creamos una columna/campo llamado "filename_nuevo" que su valor es el método index 
del DataFrame para obtener su índice y usamos .astype('str') para obtenerlo como string y a eso le añadimos el tipo de archivo, en este caso JPG"""

df['filename_nuevo'] = df.index.astype(str) + '.jpg'
df
# Out:
#         filename label filename_nuevo
# 0      10538.jpg   Cat          0.jpg
# 1      10539.jpg   Cat          1.jpg
# 2       1054.jpg   Cat          2.jpg
# 3      10540.jpg   Cat          3.jpg
# 4      10541.jpg   Cat          4.jpg
# ...          ...   ...            ...
# 24760   8588.jpg   Dog      24760.jpg
# 24761   9584.jpg   Dog      24761.jpg
# 24762      1.jpg   Dog      24762.jpg
# 24763   7968.jpg   Dog      24763.jpg
# 24764   6604.jpg   Dog      24764.jpg
#
# [24765 rows x 3 columns]

# %% [markdown]
# Como podemos observar, ya tenemos los datos con un solo nombre, evitando esto el problema "Filename collision", ahora debemos copiarlo a la carpeta donde estarán todos los archivos, esto se hace con la librería os para los paths y shutil para mover los archivos.
#
# Primero creamos la ruta base donde se encuentran todas las carpetas y sus imágenes: ..\ ..\PetImages
#
# Después debemos iterar sobre las filas del DataFrame, lo cual podemos realizarlo con el método iterrows() del DataFrame y un bucle for con tuplas (idx, fila)

# %%
ruta_base = r'..\..\PetImages'

for idx, fila in df.iterrows():
    #Ahora debemos obtener el label, el anterior nombre y el nuevo nombre que cree con sus índices
    label = fila['label']
    old_name = fila['filename']
    new_name = fila['filename_nuevo']

    #Ahora con la anterior información podemos crear los paths, donde imaginemos que label = Dog, old_name='0.jpg' y el nuevo nombre es 10.jpg
    old_path = os.path.join(ruta_base, label, old_name) # Resultado: C:\Users\PC\Desktop\Road_to_Hackathon\PetImages\Dog\0.jpg
    dir_path = os.path.join(ruta_base, 'renamed_ds')  # Resultado: C:\Users\PC\Desktop\Road_to_Hackathon\PetImages\renamed_ds (Esta carpeta la llame así porque me quedé sin ideas jaja)
    new_path = os.path.join(ruta_base, 'renamed_ds', new_name) # Resultado: C:\Users\PC\Desktop\Road_to_Hackathon\PetImages\renamed_ds\10.jpg
    
    #Ahora necesitamos hacer una condición para saber si es que existe o no el directorio renamed_ds (esto solo pa' la primera vez que ejecuto el código jajajsfaj)
    if not os.path.isdir(dir_path): # 1era ejecución: False -1: True lmao xd
        #Ahora creamos el directorio
        os.mkdir(dir_path)
    
    #Ahora copiamos el archivo
    shutil.copy(old_path, new_path)

print("Los archivos han sido copiados")
# Out:
# Los archivos han sido copiados

# %% [markdown]
# ![Imagen de la carpeta renamed_ds](../../Images/Random/folder_renamedDS.png)
#
# Ala, aparcao' ya que tenemos todos los archivos movidos, solo queda limpiar el dataframe para pasarlo a el slice de dataset para entrenamiento y validación, solo para corroborar que no haya Filename collision ejecutamos el siguiente bloque de código:

# %%
df[df['filename_nuevo'] == '0.jpg']
# Out:
#     filename label filename_nuevo
# 0  10538.jpg   Cat          0.jpg

# %% [markdown]
# Como podemos observar todavía debemos borrar la columna que podría llegar a colisiones de nombre, pero tomando como argumento la columna del DataFrame "filename_nuevo"

# %%
#Ahora borramos la columna 'filename' que tiene el problema del Filename collision, con el parámetro: inplace con el valor de True, para que modifique el DataFrame y no cree una copia.
df.drop(columns=['filename'], inplace=True)

# %%
#Renombramos la columna filename_nuevo a filename
df.rename(columns={"filename_nuevo":'filename'}, inplace=True)

# %%
#Creamos una lista con los nombres de las columnas del DataFrame
columnas = df.columns.tolist()

#Quitamos el campo/columna filename
columnas.remove('filename')

# %%
#Nomás pa' ver las columnas en la lista XD
columnas
# Out:
# ['label']

# %%
#Insertamos en la posición 0 el argumento 'filename'
columnas.insert(0, 'filename')

# %%
#Volvemos a mostrar, ala aparcao' de nuevo pa' poder ponerlas en el DataFrame
columnas
# Out:
# ['filename', 'label']

# %%
#Renombramos las columnas del DataFrame y lo mostramos pa' corroborar
df = df[columnas]
df
# Out:
#         filename label
# 0          0.jpg   Cat
# 1          1.jpg   Cat
# 2          2.jpg   Cat
# 3          3.jpg   Cat
# 4          4.jpg   Cat
# ...          ...   ...
# 24760  24760.jpg   Dog
# 24761  24761.jpg   Dog
# 24762  24762.jpg   Dog
# 24763  24763.jpg   Dog
# 24764  24764.jpg   Dog
#
# [24765 rows x 2 columns]

# %%
#Ahora si ejecutamos el método que ya teníamos anteriormente, pero con el argumento filename porque ya renombramos el.
df[df['filename'] == '0.jpg']
# Out:
#   filename label
# 0    0.jpg   Cat

# %% [markdown]
# Ahora que tenemos el DataFrame, podemos crear la clase para crear el Dataset customizado para el modelo que entrenaremos.
#
# El código es similar al que nos otorga la documentación de PyTorch, donde como instancias declaramos 4 la cual es el **DataFrame**, el **directorio de imágenes**, **transformador de imágenes** (normalizaciones, convertirlo a tensor de PyTorch, DataAugmentation, etc.) y **transformador de etiquetas** (convertir de one-hot a label encoding o de label encoding a logits [probabilidades])

# %%
class CustomDS(Dataset):
    def __init__(self, dataframe, images_dir, transform=None, target_transform=None): #Parámetros modificables
        self.labels = dataframe #Le pasamos el DataFrame que ya habíamos hecho sin el problema de Filename collision
        self.directory = images_dir #Ruta al directorio de imágenes
        self.transform_data = transform #Transformador de la imagen
        self.target_transform = target_transform #Transformador de etiquetas
        self.mapping = {"Cat": 0, "Dog": 1} #Mapeo de etiquetas

    def __len__(self):
        return len(self.labels) #Solamente obtiene la cantidad de elementos

    def __getitem__(self, idx):
        label_df = self.labels.iloc[idx, 1] #Obtiene el elemento de la fila (supongamos idx = 0) 0 y columna 1, lo que sería el elemento de la posición [0, 1] si vieramos al DataFrame como una matriz
        img_path = os.path.join(self.directory, self.labels.iloc[idx, 0]) #Generamos el path de donde se encuentran las imágenes (Notese que solo accedo al elemento, porque ya no hay distinción entre imágenes hablando de las carpetas)
        img = Image.open(img_path).convert('RGB') #Abrimos la imagen con PIL para saber si la imagen no está corrupta o dañada y si esto es cierto, la convertimos a RGB para tener 3 canales en el tensor
        img_label = self.mapping[label_df] #Mapeamos la etiqueta, es decir, si la etiqueta es Cat, la convierte en 0 o si es Dog la convierte en 1
        if self.transform_data: #Revisamos si se pasaron transformadores para los datos
            img = self.transform_data(img)
        if self.target_transform: #Lo mismo, pero para etiquetado
            img_label = self.target_transform(img_label)
        return img, img_label #Retornamos la imagen y su etiqueta

# %% [markdown]
# Solo quiero mencionar dos cosas que no mencioné en el código anterior, el código anterior en la sección de "transformador de etiquetas" me refiero al hecho que la etiqueta, puede permanecer como un entero o como un tensor donde ese tensor tiene el formato de **One-hot encoding** ¿A qué hace referencia este término? Es simplemente que si tenemos por ejemplo... la etiqueta 0, este número entero se convierte a un tensor donde se marca la posición 0 del tensor como un 1 y la demás 0 para determinar que es un 0, algo más gráfico sería:
#
# 0 -> torch.nn.functional.one_hot(torch.Tensor(label), num_classes=2) -> tensor([1, 0]) //La posición 0 del tensor marcado por el número 1, es el que determina a qué clase pertenece.
#
# Además el otro punto que quería mencionar es que al momento en el que se cargan los archivos, es donde el problema de **Filename collision** es el que podría generar el problema de carga distinta imagen a la que el etiquetado sugiere. Para ser más claros pondré un ejemplo:
#
# Imaginemos que el modelo carga la imagen 0.jpg de la etiqueta "Gato", pero el modelo carga la otra imagen de la etiqueta "Perro" lo que causa que el modelo aprenda al revés el generalizar las imágenes

# %%
#Ahora debemos dividir el DataFrame con train_test_split de Scikit-learn (Opté por usar dicho método de Scikit porque ya esta optimizado y además es más sencillo de usar [no debo reinventar la rueda])
#con 20% de los datos para el dataset de validación y 80% para entrenar el modelo, además dividiremos el dataset de validación, para obtener una métrica más confiable con imágenes que nunca ha visto

train_df, val_df = train_test_split(
    df,
    test_size = 0.2,
    stratify=df['label'],
    random_state=788
)

val_df, dev_df = train_test_split(
    val_df,
    test_size=0.1,
    stratify=val_df['label'],
    random_state=788
)

# %% [markdown]
# Una vez tenemos los DataFrames de entrenamiento, validación y prueba / dev (asi lo llaman coloquialmente xd), podemos ahora si crear una instancia de cada uno de los 3 datasets para el modelo, pero antes revisemos los tamaños de todos ellos.

# %%
general_path = r'C:\Users\PC\Desktop\Road_to_Hackathon\PetImages\renamed_ds'

print(f"Train size: {len(train_df)}, Test size: {len(val_df)}, Dev size: {len(dev_df)}")

transformador = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

#Generación de las instancias de las clases CustomDS
train_dataset = CustomDS(dataframe=train_df, images_dir=general_path, transform=transformador)
val_dataset = CustomDS(dataframe=val_df, images_dir=general_path, transform=transformador)
dev_dataset = CustomDS(dataframe=dev_df, images_dir=general_path, transform=transformador)

#Generción de los DataLoaders
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
dev_dataloader = DataLoader(dev_dataset, batch_size=64, shuffle=True)
# Out:
# Train size: 19812, Test size: 4457, Dev size: 496

# %% [markdown]
# Una vez tenemos los datos (aún falta limpieza, pero ahorita más adelante lo resolvemos), generamos la arquitectura del modelo, pensé en el concepto de ResNet de usar dos convoluciones antes de pasar por un Pooling, solo que aquí opte por cortalo mediante un stride, algo que en el modelo final pienso cambiarlo por un MaxPooling porque para este problema solo debemos saber qué es, no debemos saber donde está y qué es (en ese caso stride = 2 está mejor que MaxPooling) ya que MaxPooling hace que se enfoque más en el objeto que más activaciones tuvo que en el que menos tuvo, filtrando algo de ruido de la imagen

# %%
#Aquí determinamos el dispositivo donde se harán todos los cálculos, en mi caso es una RTX 5070 TI TUF GAMING con 16 GB de VRam, pero optimizada para entrenamiento de modelos de Deep Learning por parte de NVIDIA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#Generamos la clase del modelo con la herencia de nn.Module
class Modelo(nn.Module):
    def __init__(self):
        super(Modelo, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=(3, 3), padding = 1) #Input = 128, 128, 3
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=(3, 3)) #63
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3, 3), padding = 1)
        self.conv4 = nn.Conv2d(in_channels= 32, out_channels=64, kernel_size=(3, 3)) #31
        self.conv5 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3, 3), padding = 1)
        self.conv6 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=(3, 3)) #15
        self.conv7 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=(3, 3)) #13
        self.conv8 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=(3, 3)) #6
        self.maxpool = nn.MaxPool2d((2, 2))

        self.avg = nn.AdaptiveAvgPool2d((1, 1)) # batch, 128, 1, 1

        self.dense1 = nn.Linear(in_features=128, out_features=64)  
        self.dense2 = nn.Linear(in_features=64, out_features=2)

    def forward(self, x):
        x = f.relu(self.conv1(x))
        x = f.leaky_relu(self.maxpool(self.conv2(x)))
        x = f.relu(self.conv3(x))
        x = f.leaky_relu(self.maxpool(self.conv4(x)))
        x = f.relu(self.conv5(x))
        x = f.leaky_relu(self.maxpool(self.conv6(x)))
        x = f.relu(self.conv7(x))
        x = f.leaky_relu(self.maxpool(self.conv8(x)))

        x = self.avg(x)
        
        x = torch.flatten(x, 1)
        x = f.relu(self.dense1(x))
        x = self.dense2(x)

        return x

# %%
model = Modelo().to(device)
model.parameters
# Out:
# <bound method Module.parameters of Modelo(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (maxpool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (avg): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dense1): Linear(in_features=128, out_features=64, bias=True)
#   (dense2): Linear(in_features=64, out_features=2, bias=True)
# )>

# %%
function_loss = nn.CrossEntropyLoss()
optimizador = torch.optim.Adam(model.parameters(), lr=1e-4) 
"""
epochs = 100
best_loss = float('inf')
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct_preds = 0
    total_samples = 0

    for i, (images, labels) in enumerate(train_dataloader):
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = function_loss(outputs, labels)
        if loss < best_loss:
            best_model = loss
            torch.save(model.state_dict(), "Best_Model_Checkpoint.pth")
        optimizador.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) 
        optimizador.step()

    print(f'Época [{epoch+1}/{epochs}], loss: {loss.item():.4f}')

print('Entrenamiento finalizado.')
"""
# Out:
# '\nepochs = 100\nbest_loss = float(\'inf\')\nfor epoch in range(epochs):\n    model.train()\n    running_loss = 0.0\n    correct_preds = 0\n    total_samples = 0\n\n    for i, (images, labels) in enumerate(train_dataloader):\n        images = images.to(device)\n        labels = labels.to(device)\n\n        outputs = model(images)\n        loss = function_loss(outputs, labels)\n        if loss < best_loss:\n            best_model = loss\n            torch.save(model.state_dict(), "Best_Model_Checkpoint.pth")\n        optimizador.zero_grad()\n        loss.backward()\n        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) \n        optimizador.step()\n\n    print(f\'Época [{epoch+1}/{epochs}], loss: {loss.item():.4f}\')\n\nprint(\'Entrenamiento finalizado.\')\n'

# %%
#Ahora crearemos una función para limpiar datos corruptos o dañados usando la librería PIL con la clase Image y métodos open, para quitar el warning "UserWarning: Truncated File Read warnings.warn(str(msg))"
def clean_data(DirPath, DataFrame=None):
    DatosInaccesibles = []
    for _, row in DataFrame.iterrows():
        path = os.path.join(DirPath, row['filename'])
        try:
            with Image.open(path) as img:
                img.verify()
            with Image.open(path) as img:
                img.load()
        except (UnidentifiedImageError, OSError, ValueError) as ex:
            DatosInaccesibles.append(path)        
    return DatosInaccesibles

dictInaccesibles={}

ds_dir = r'..\..\PetImages'
df_dog = pd.read_csv(r'..\..\Labels\labels_Dog.csv')
df_cat = pd.read_csv(r'..\..\Labels\labels_Cat.csv')

print(df_dog, df_cat)

data_to_clean = [(os.path.join(ds_dir, 'Dog'), df_dog), (os.path.join(ds_dir, 'Cat'), df_cat)]

for path, dataframe in data_to_clean:
    print(path)
    dir_name = os.path.basename(path)
    dictInaccesibles[dir_name] = clean_data(DirPath=path, DataFrame=dataframe)

print(f"Archivos inaccesibles o dañados encontrados: {dictInaccesibles}")
# Out:
#        filename  label
# 0         0.jpg    Dog
# 1         1.jpg    Dog
# 2        10.jpg    Dog
# 3       100.jpg    Dog
# 4      1000.jpg    Dog
# ...         ...    ...
# 12358  9995.jpg    Dog
# 12359  9996.jpg    Dog
# 12360  9997.jpg    Dog
# 12361  9998.jpg    Dog
# 12362  9999.jpg    Dog
#
# [12363 rows x 2 columns]        filename  label
# 0         0.jpg    Cat
# 1         1.jpg    Cat
# 2        10.jpg    Cat
# 3       100.jpg    Cat
# 4      1000.jpg    Cat
# ...         ...    ...
# 12397  9995.jpg    Cat
# 12398  9996.jpg    Cat
# 12399  9997.jpg    Cat
# 12400  9998.jpg    Cat
# 12401  9999.jpg    Cat
#
# [12402 rows x 2 columns]
# ..\..\PetImages\Dog
# ..\..\PetImages\Cat
# Archivos inaccesibles o dañados encontrados: {'Dog': [], 'Cat': []}

# %%
#Este fragmento lo hice para saber que imagen daba un warning y podría estar causando problemas de loss inestable
df_dog[df_dog['filename'] == '9040.jpg'].index

df_dog.iloc[11313, 0]
# Out:
# '9042.jpg'

# %%
class customDSAlone(Dataset):
    def __init__(self, dataframe, img_path, transform = None, target_transform = None):
        self.dataframe = dataframe
        self.img_dir = img_path
        self.transform = transform
        self.target_transform = target_transform
        self.mapping = {'Cat': 0, 'Dog':1}
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        label = self.dataframe.iloc[idx, 1]
        _filename = self.dataframe.iloc[idx, 0]
        path_img = os.path.join(self.img_dir, label, _filename)
        image = Image.open(path_img).convert('RGB')
        mapped_label = self.mapping[label]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, mapped_label, _filename

# %%
DogDF = pd.read_csv(r'..\..\Labels\labels_Dog.csv')
CatDF = pd.read_csv(r'..\..\Labels\labels_Cat.csv')
DogDS = customDSAlone(dataframe=DogDF, img_path=r'..\..\Petimages', transform=transformador)
CatDS = customDSAlone(dataframe=CatDF, img_path=r'..\..\Petimages', transform=transformador)
DogDL = DataLoader(dataset = DogDS, batch_size=64, shuffle=True)
CatDL = DataLoader(dataset = CatDS, batch_size=64, shuffle=True)

# %%
model = Modelo()
model.load_state_dict(torch.load('Best_Model_Checkpoint.pth', map_location=device))

def MismatchLabeling(model, dataloader, device, FunctionLoss):
    val_loss = 0.0
    total_samples = len(dataloader.dataset)
    correct = 0
    model.eval()
    model = model.to(device)
    resultados = []
    with torch.no_grad():
        for images, labels, filename in dataloader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images) #Aquí devuelve logits, por ejemplo si es solo 2 características (sería...) [2.1, 3.7]
            loss = FunctionLoss(outputs, labels) * images.size(0) #Acá se usa images.size(0) porque si tenemos batch = 32, pero con un loss 0.2, eso es el promedio, si quieres el general del batch, sería a la inversa, multiplicar por el total del batch
            val_loss += loss.item()
            prob = torch.nn.functional.softmax(outputs, 1)
            confianza, predict = torch.max(prob, 1)
            for i in range(images.size(0)):
                resultados.append({
                    'filename': filename[i],
                    'true_label': labels[i].item(),
                    'predicted_label': predict[i].item(),
                    'max_prob': confianza[i].item()
                })
                if labels[i] == predict[i]:
                    correct += 1
    val_loss /= len(dataloader.dataset)
    precision = (correct / total_samples) * 100
    return (f'El valor de pérdida del mdoelo es: {val_loss:.4f}, con una precisión de: {precision:.4f}', resultados)

# %%
Asd = MismatchLabeling(model = model, dataloader = DogDL, device = device, FunctionLoss = function_loss)
text, results = Asd

# %%
print(text)
# Out:
# El valor de pérdida del mdoelo es: 0.0856, con una precisión de: 97.0315

# %%
results
# Out:
# [{'filename': '9797.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.846744179725647},
#  {'filename': '9165.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999864935874939},
#  {'filename': '1161.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9845747947692871},
#  {'filename': '3449.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9992474317550659},
#  {'filename': '936.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.99750816822052},
#  {'filename': '6336.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9856225848197937},
#  {'filename': '3469.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9937103986740112},
#  {'filename': '8527.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9003551602363586},
#  {'filename': '6492.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9991887211799622},
#  {'filename': '12442.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.984207272529602},
#  {'filename': '5359.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9744174480438232},
#  {'filename': '1312.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999406337738037},
#  {'filename': '2717.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9987247586250305},
#  {'filename': '9925.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9992936849594116},
#  {'filename': '4309.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9990710020065308},
#  {'filename': '10736.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999972939491272},
#  {'filename': '3758.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.994828999042511},
#  {'filename': '113.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999963045120239},
#  {'filename': '4468.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9252194166183472},
#  {'filename': '519.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9087721109390259},
#  {'filename': '4813.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9966603517532349},
#  {'filename': '671.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9960743188858032},
#  {'filename': '7573.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.998078465461731},
#  {'filename': '4600.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.6045182943344116},
#  {'filename': '9003.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9992744326591492},
#  {'filename': '2807.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.7448428869247437},
#  {'filename': '3290.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995625615119934},
#  {'filename': '7650.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9928104281425476},
#  {'filename': '6382.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9849557280540466},
#  {'filename': '6583.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.753686249256134},
#  {'filename': '12301.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9707329273223877},
#  {'filename': '7964.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9974506497383118},
#  {'filename': '10159.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9968751668930054},
#  {'filename': '10837.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.997089684009552},
#  {'filename': '11902.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973781108856201},
#  {'filename': '531.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998264908790588},
#  {'filename': '11277.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9568395018577576},
#  {'filename': '8240.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9891172051429749},
#  {'filename': '6762.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989859461784363},
#  {'filename': '6940.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989577531814575},
#  {'filename': '8901.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.998145580291748},
#  {'filename': '7161.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9956831932067871},
#  {'filename': '9873.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979797005653381},
#  {'filename': '11668.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9610790014266968},
#  {'filename': '7638.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999817609786987},
#  {'filename': '11271.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973142743110657},
#  {'filename': '6799.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9925410747528076},
#  {'filename': '5991.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.991155743598938},
#  {'filename': '2959.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998822212219238},
#  {'filename': '11820.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9963741898536682},
#  {'filename': '2673.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998798370361328},
#  {'filename': '2053.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9925967454910278},
#  {'filename': '11004.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9522459506988525},
#  {'filename': '1065.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9981991648674011},
#  {'filename': '8378.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998230338096619},
#  {'filename': '2421.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9975885152816772},
#  {'filename': '6235.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9936196208000183},
#  {'filename': '8796.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9990618824958801},
#  {'filename': '10261.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.6252899765968323},
#  {'filename': '12331.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.998371422290802},
#  {'filename': '320.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979099631309509},
#  {'filename': '7209.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9987373948097229},
#  {'filename': '1545.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994788765907288},
#  {'filename': '6594.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.99983811378479},
#  {'filename': '737.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9925685524940491},
#  {'filename': '11052.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9928007125854492},
#  {'filename': '5424.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9315688610076904},
#  {'filename': '10967.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8007983565330505},
#  {'filename': '10512.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9955596923828125},
#  {'filename': '3646.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9992706179618835},
#  {'filename': '11762.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9985548853874207},
#  {'filename': '6351.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9176086187362671},
#  {'filename': '11579.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9580598473548889},
#  {'filename': '11744.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9940776824951172},
#  {'filename': '5112.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999993085861206},
#  {'filename': '4827.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9902504682540894},
#  {'filename': '1270.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9992827773094177},
#  {'filename': '10474.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9958240985870361},
#  {'filename': '11572.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998756647109985},
#  {'filename': '9401.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.994616687297821},
#  {'filename': '315.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9870564937591553},
#  {'filename': '8773.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995738863945007},
#  {'filename': '8556.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.5266851186752319},
#  {'filename': '10466.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9948561191558838},
#  {'filename': '4284.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999419450759888},
#  {'filename': '5034.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.6496992111206055},
#  {'filename': '12056.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9820432066917419},
#  {'filename': '5136.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9991815686225891},
#  {'filename': '9309.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9936151504516602},
#  {'filename': '12211.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999525547027588},
#  {'filename': '5733.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8281571865081787},
#  {'filename': '1692.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8991192579269409},
#  {'filename': '9337.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9967502355575562},
#  {'filename': '12226.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999856948852539},
#  {'filename': '9531.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999554455280304},
#  {'filename': '9271.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9854856729507446},
#  {'filename': '12250.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9953124523162842},
#  {'filename': '11379.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8703604340553284},
#  {'filename': '4598.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9910237789154053},
#  {'filename': '7899.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9470182657241821},
#  {'filename': '4180.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9963445067405701},
#  {'filename': '6157.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999659061431885},
#  {'filename': '8725.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9886941313743591},
#  {'filename': '10161.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9773681163787842},
#  {'filename': '4998.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.6570315361022949},
#  {'filename': '5615.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9704887866973877},
#  {'filename': '5498.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8987963199615479},
#  {'filename': '3128.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9553394317626953},
#  {'filename': '8273.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997383952140808},
#  {'filename': '4304.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9935777187347412},
#  {'filename': '10073.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9894702434539795},
#  {'filename': '5350.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994754195213318},
#  {'filename': '2757.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9940217137336731},
#  {'filename': '6804.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995625615119934},
#  {'filename': '1925.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8070287704467773},
#  {'filename': '9721.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999048709869385},
#  {'filename': '1912.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9985784292221069},
#  {'filename': '5430.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9570538997650146},
#  {'filename': '8106.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9957744479179382},
#  {'filename': '4688.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9983129501342773},
#  {'filename': '4028.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9988740086555481},
#  {'filename': '4837.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9878180027008057},
#  {'filename': '10110.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9942312240600586},
#  {'filename': '4124.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999191761016846},
#  {'filename': '627.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9906082153320312},
#  {'filename': '6700.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999669790267944},
#  {'filename': '865.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9898939728736877},
#  {'filename': '11461.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9742605090141296},
#  {'filename': '3600.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9935001730918884},
#  {'filename': '614.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9574064612388611},
#  {'filename': '5856.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9623778462409973},
#  {'filename': '10228.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9970259070396423},
#  {'filename': '3841.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8697124719619751},
#  {'filename': '8508.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998315572738647},
#  {'filename': '12058.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993201494216919},
#  {'filename': '8620.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9990682005882263},
#  {'filename': '11756.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999295711517334},
#  {'filename': '8850.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999414682388306},
#  {'filename': '3516.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9988706707954407},
#  {'filename': '5529.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9809804558753967},
#  {'filename': '7541.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9642575979232788},
#  {'filename': '3524.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8567982912063599},
#  {'filename': '10004.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999667406082153},
#  {'filename': '9715.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999812841415405},
#  {'filename': '7751.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8718482255935669},
#  {'filename': '9024.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9837809801101685},
#  {'filename': '3699.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9969862103462219},
#  {'filename': '1135.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.998145580291748},
#  {'filename': '1617.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9984942674636841},
#  {'filename': '8455.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.738172709941864},
#  {'filename': '703.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999964237213135},
#  {'filename': '7408.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.797010064125061},
#  {'filename': '4191.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9355238080024719},
#  {'filename': '5652.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999959468841553},
#  {'filename': '7567.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999988317489624},
#  {'filename': '9996.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999383807182312},
#  {'filename': '11485.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999716281890869},
#  {'filename': '1457.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999897480010986},
#  {'filename': '2155.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9942264556884766},
#  {'filename': '11283.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997461438179016},
#  {'filename': '9058.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999942421913147},
#  {'filename': '5752.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9798163771629333},
#  {'filename': '8821.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973658919334412},
#  {'filename': '11372.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9959828853607178},
#  {'filename': '7273.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.7350144386291504},
#  {'filename': '3017.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8577229976654053},
#  {'filename': '9268.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999526858329773},
#  {'filename': '3925.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999755620956421},
#  {'filename': '11768.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9906505346298218},
#  {'filename': '75.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9827689528465271},
#  {'filename': '2196.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9945377707481384},
#  {'filename': '10732.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.6764665246009827},
#  {'filename': '6356.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9982774257659912},
#  {'filename': '9803.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.5050572156906128},
#  {'filename': '4753.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9690565466880798},
#  {'filename': '9484.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996187686920166},
#  {'filename': '3201.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9932355284690857},
#  {'filename': '8146.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9980338215827942},
#  {'filename': '6316.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9963424801826477},
#  {'filename': '1391.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9940722584724426},
#  {'filename': '11176.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979027509689331},
#  {'filename': '10410.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979408383369446},
#  {'filename': '5264.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.6139416098594666},
#  {'filename': '12096.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.998416543006897},
#  {'filename': '5195.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997842907905579},
#  {'filename': '9711.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.996157705783844},
#  {'filename': '1370.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9798532724380493},
#  {'filename': '10080.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.866222620010376},
#  {'filename': '736.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9981671571731567},
#  {'filename': '3343.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999841451644897},
#  {'filename': '2611.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9984307885169983},
#  {'filename': '8419.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9759323596954346},
#  {'filename': '523.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999908208847046},
#  {'filename': '3153.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8655393123626709},
#  {'filename': '4379.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999958276748657},
#  {'filename': '10415.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9952384233474731},
#  {'filename': '4071.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9903016686439514},
#  {'filename': '6384.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9988732933998108},
#  {'filename': '11630.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999594688415527},
#  {'filename': '11037.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9981932044029236},
#  {'filename': '9069.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9446184039115906},
#  {'filename': '2484.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9982812404632568},
#  {'filename': '10117.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9481750726699829},
#  {'filename': '504.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.996440589427948},
#  {'filename': '3771.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9488347172737122},
#  {'filename': '1574.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995641112327576},
#  {'filename': '3704.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999105930328369},
#  {'filename': '1203.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.7657659649848938},
#  {'filename': '2272.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9225770831108093},
#  {'filename': '1413.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8429858088493347},
#  {'filename': '10934.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997000694274902},
#  {'filename': '7356.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9711664915084839},
#  {'filename': '6521.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998117089271545},
#  {'filename': '7256.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9953437447547913},
#  {'filename': '1155.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998979568481445},
#  {'filename': '11257.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9023463726043701},
#  {'filename': '1301.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999728202819824},
#  {'filename': '7798.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.5504559874534607},
#  {'filename': '2671.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996539354324341},
#  {'filename': '4207.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9589980244636536},
#  {'filename': '8958.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.8302710056304932},
#  {'filename': '6438.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9766289591789246},
#  {'filename': '3986.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9486986398696899},
#  {'filename': '3310.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9988388419151306},
#  {'filename': '9403.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9991826415061951},
#  {'filename': '2112.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997996687889099},
#  {'filename': '4964.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9964511394500732},
#  {'filename': '11005.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9992792010307312},
#  {'filename': '7560.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9870061874389648},
#  {'filename': '2548.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999721050262451},
#  {'filename': '2016.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.9521769881248474},
#  {'filename': '3317.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9983925223350525},
#  {'filename': '11404.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9988346695899963},
#  {'filename': '8196.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9554846882820129},
#  {'filename': '156.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9774954915046692},
#  {'filename': '4859.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9978998899459839},
#  {'filename': '6904.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9702985882759094},
#  {'filename': '6396.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9426261186599731},
#  {'filename': '3814.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9886674284934998},
#  {'filename': '8349.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.90399569272995},
#  {'filename': '4547.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9831426739692688},
#  {'filename': '12088.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9600697755813599},
#  {'filename': '2338.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999434947967529},
#  {'filename': '8653.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.6657086610794067},
#  {'filename': '1939.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9757425785064697},
#  {'filename': '1008.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993165731430054},
#  {'filename': '9167.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.832663357257843},
#  {'filename': '5792.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.5680540204048157},
#  {'filename': '5612.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9449693560600281},
#  {'filename': '12313.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9986777901649475},
#  {'filename': '3186.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973801970481873},
#  {'filename': '11536.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999425411224365},
#  {'filename': '7066.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9117579460144043},
#  {'filename': '1755.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9963829517364502},
#  {'filename': '9620.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9694105386734009},
#  {'filename': '3448.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9933810234069824},
#  {'filename': '11879.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.6567672491073608},
#  {'filename': '9597.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9711130857467651},
#  {'filename': '797.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999790191650391},
#  {'filename': '1503.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989110231399536},
#  {'filename': '8846.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9678822159767151},
#  {'filename': '9718.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9368287324905396},
#  {'filename': '357.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9945493340492249},
#  {'filename': '8705.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998130202293396},
#  {'filename': '7509.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9557885527610779},
#  {'filename': '3621.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9503556489944458},
#  {'filename': '7954.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996683597564697},
#  {'filename': '5099.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999717473983765},
#  {'filename': '4239.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999985694885254},
#  {'filename': '6400.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9905920624732971},
#  {'filename': '8819.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9916359186172485},
#  {'filename': '4962.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989674091339111},
#  {'filename': '7902.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9491163492202759},
#  {'filename': '9836.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9863574504852295},
#  {'filename': '11471.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997686743736267},
#  {'filename': '1199.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9980167150497437},
#  {'filename': '3976.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989595413208008},
#  {'filename': '10283.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999945163726807},
#  {'filename': '10550.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9870848059654236},
#  {'filename': '94.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979938268661499},
#  {'filename': '11211.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9882234930992126},
#  {'filename': '6741.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973428845405579},
#  {'filename': '10624.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9992470741271973},
#  {'filename': '2675.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9950326681137085},
#  {'filename': '11632.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9638611674308777},
#  {'filename': '7534.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9492617249488831},
#  {'filename': '11030.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9981824159622192},
#  {'filename': '11779.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9991694688796997},
#  {'filename': '8772.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9460911750793457},
#  {'filename': '12336.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9788141846656799},
#  {'filename': '7036.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994112253189087},
#  {'filename': '8209.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994499087333679},
#  {'filename': '1436.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.993245542049408},
#  {'filename': '3611.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999046325683594},
#  {'filename': '4936.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999981164932251},
#  {'filename': '2656.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9876377582550049},
#  {'filename': '10006.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9251791834831238},
#  {'filename': '11445.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9438834190368652},
#  {'filename': '6287.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9305548071861267},
#  {'filename': '8720.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973728656768799},
#  {'filename': '5331.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999295473098755},
#  {'filename': '2370.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9242777228355408},
#  {'filename': '12161.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999902248382568},
#  {'filename': '9045.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9969744682312012},
#  {'filename': '6814.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9937605261802673},
#  {'filename': '10845.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9659727811813354},
#  {'filename': '10340.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9788970947265625},
#  {'filename': '3767.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9880794882774353},
#  {'filename': '11056.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999009370803833},
#  {'filename': '10780.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.996880054473877},
#  {'filename': '3741.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989963173866272},
#  {'filename': '3073.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9988484382629395},
#  {'filename': '6915.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9954838752746582},
#  {'filename': '1949.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.6169096827507019},
#  {'filename': '7565.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998302459716797},
#  {'filename': '6239.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999523162841797},
#  {'filename': '12279.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9575397372245789},
#  {'filename': '2398.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8177617192268372},
#  {'filename': '4887.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9816961288452148},
#  {'filename': '8115.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999868869781494},
#  {'filename': '8917.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9980130195617676},
#  {'filename': '3282.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999907374382019},
#  {'filename': '4077.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.6414275169372559},
#  {'filename': '10070.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989733695983887},
#  {'filename': '7429.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9251202940940857},
#  {'filename': '8214.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8390952348709106},
#  {'filename': '6163.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.7087520360946655},
#  {'filename': '10138.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996379613876343},
#  {'filename': '2533.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9689503312110901},
#  {'filename': '3689.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999575614929199},
#  {'filename': '1780.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9083531498908997},
#  {'filename': '5313.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9986609220504761},
#  {'filename': '5545.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.995513379573822},
#  {'filename': '11081.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9428852796554565},
#  {'filename': '2722.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999716281890869},
#  {'filename': '10719.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9978734254837036},
#  {'filename': '5783.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9433599710464478},
#  {'filename': '6764.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9915251135826111},
#  {'filename': '8542.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9955484867095947},
#  {'filename': '5057.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.997270405292511},
#  {'filename': '6770.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.95803302526474},
#  {'filename': '643.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.977977991104126},
#  {'filename': '9547.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8843761086463928},
#  {'filename': '9457.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999336302280426},
#  {'filename': '791.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9656955599784851},
#  {'filename': '1400.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994958639144897},
#  {'filename': '1725.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999492168426514},
#  {'filename': '8797.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9140646457672119},
#  {'filename': '10376.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989620447158813},
#  {'filename': '1271.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9421746730804443},
#  {'filename': '877.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9919106364250183},
#  {'filename': '9897.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979105591773987},
#  {'filename': '8222.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979937076568604},
#  {'filename': '9788.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9898375272750854},
#  {'filename': '904.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999190628528595},
#  {'filename': '2453.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997815489768982},
#  {'filename': '917.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9981682300567627},
#  {'filename': '7094.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9877818822860718},
#  {'filename': '7819.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9944549202919006},
#  {'filename': '5105.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995648264884949},
#  {'filename': '9665.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996029734611511},
#  {'filename': '5956.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.972399890422821},
#  {'filename': '4589.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9949511289596558},
#  {'filename': '9476.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999971389770508},
#  {'filename': '1864.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9854280352592468},
#  {'filename': '8962.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999116659164429},
#  {'filename': '3101.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.937435507774353},
#  {'filename': '8345.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994798302650452},
#  {'filename': '258.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9990630745887756},
#  {'filename': '7930.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.994346559047699},
#  {'filename': '5884.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8162636756896973},
#  {'filename': '9891.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999980926513672},
#  {'filename': '6270.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9913124442100525},
#  {'filename': '3523.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9437454342842102},
#  {'filename': '4814.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9834590554237366},
#  {'filename': '3572.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9981876015663147},
#  {'filename': '9446.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9534452557563782},
#  {'filename': '3404.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9046967625617981},
#  {'filename': '12244.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8664705157279968},
#  {'filename': '6297.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.7352855801582336},
#  {'filename': '7153.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999852180480957},
#  {'filename': '5064.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8950303792953491},
#  {'filename': '879.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979508519172668},
#  {'filename': '10877.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973244667053223},
#  {'filename': '4146.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9967150688171387},
#  {'filename': '7610.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9962598085403442},
#  {'filename': '1959.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9316505789756775},
#  {'filename': '11272.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9965739250183105},
#  {'filename': '6977.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998594522476196},
#  {'filename': '10048.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998980760574341},
#  {'filename': '3242.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9987480640411377},
#  {'filename': '3491.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9919648170471191},
#  {'filename': '7730.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999904632568359},
#  {'filename': '959.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9976869821548462},
#  {'filename': '11488.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9963169097900391},
#  {'filename': '10323.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9913454055786133},
#  {'filename': '1943.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.978597104549408},
#  {'filename': '12431.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9344691634178162},
#  {'filename': '3547.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999071359634399},
#  {'filename': '3286.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9346950650215149},
#  {'filename': '10659.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.5187631249427795},
#  {'filename': '8113.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9986515641212463},
#  {'filename': '973.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9785221219062805},
#  {'filename': '821.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.995496392250061},
#  {'filename': '15.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9918115139007568},
#  {'filename': '1591.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9191062450408936},
#  {'filename': '3187.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999834299087524},
#  {'filename': '3865.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9970768690109253},
#  {'filename': '7887.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9894202947616577},
#  {'filename': '10879.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9947198629379272},
#  {'filename': '9447.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9965319633483887},
#  {'filename': '3321.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9371846914291382},
#  {'filename': '11021.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9881224036216736},
#  {'filename': '6427.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999908447265625},
#  {'filename': '1815.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9345637559890747},
#  {'filename': '891.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9853947162628174},
#  {'filename': '754.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973594546318054},
#  {'filename': '8443.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.959330677986145},
#  {'filename': '7955.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9982099533081055},
#  {'filename': '9825.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9986228942871094},
#  {'filename': '11467.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997710585594177},
#  {'filename': '6651.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993353486061096},
#  {'filename': '7312.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9815104007720947},
#  {'filename': '2902.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995664954185486},
#  {'filename': '2930.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9726574420928955},
#  {'filename': '3675.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9991378784179688},
#  {'filename': '8632.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9968045949935913},
#  {'filename': '10485.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9608162641525269},
#  {'filename': '1282.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9991076588630676},
#  {'filename': '4169.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9968519806861877},
#  {'filename': '958.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997227787971497},
#  {'filename': '1412.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999977350234985},
#  {'filename': '10791.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9316741824150085},
#  {'filename': '1091.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9948976635932922},
#  {'filename': '1526.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989812970161438},
#  {'filename': '4173.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9884234070777893},
#  {'filename': '5443.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9720478653907776},
#  {'filename': '5423.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9491608738899231},
#  {'filename': '4381.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9965677261352539},
#  {'filename': '4901.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999983549118042},
#  {'filename': '8845.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998682737350464},
#  {'filename': '11662.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999321699142456},
#  {'filename': '10195.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9976108074188232},
#  {'filename': '374.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8727285861968994},
#  {'filename': '3637.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.9175600409507751},
#  {'filename': '6079.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9963891506195068},
#  {'filename': '9908.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997442364692688},
#  {'filename': '3824.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996157884597778},
#  {'filename': '74.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.980891764163971},
#  {'filename': '4946.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9948491454124451},
#  {'filename': '8597.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8842025399208069},
#  {'filename': '11949.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9982624650001526},
#  {'filename': '3998.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997603297233582},
#  {'filename': '1332.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9606135487556458},
#  {'filename': '3354.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994397759437561},
#  {'filename': '1739.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.988811731338501},
#  {'filename': '5851.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9987678527832031},
#  {'filename': '7946.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9978983402252197},
#  {'filename': '9483.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.994652509689331},
#  {'filename': '7230.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9878742098808289},
#  {'filename': '12384.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9985235333442688},
#  {'filename': '5179.jpg',
#   'true_label': 1,
# ...
#   'predicted_label': 1,
#   'max_prob': 0.9999995231628418},
#  {'filename': '7752.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.995587944984436},
#  {'filename': '1867.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9972248077392578},
#  {'filename': '11190.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999713897705078},
#  {'filename': '4140.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.988318145275116},
#  {'filename': '12413.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9935530424118042},
#  {'filename': '6468.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999154806137085},
#  {'filename': '3882.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9594508409500122},
#  {'filename': '12060.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9941852688789368},
#  {'filename': '10774.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9940004348754883},
#  {'filename': '8190.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996871948242188},
#  {'filename': '4080.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989903569221497},
#  {'filename': '6889.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9958297610282898},
#  {'filename': '7884.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9939305782318115},
#  {'filename': '4907.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9787024259567261},
#  {'filename': '5512.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9731358289718628},
#  {'filename': '7474.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998853206634521},
#  {'filename': '6367.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9868701100349426},
#  {'filename': '7220.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9985589385032654},
#  {'filename': '2056.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.992933988571167},
#  {'filename': '8029.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8699256777763367},
#  {'filename': '10707.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995761513710022},
#  {'filename': '9983.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.7562109231948853},
#  {'filename': '8820.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995743632316589},
#  {'filename': '5893.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9985870122909546},
#  {'filename': '7392.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9416037797927856},
#  {'filename': '5023.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9923615455627441},
#  {'filename': '1249.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9954448938369751},
#  {'filename': '11842.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9968642592430115},
#  {'filename': '1905.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9983079433441162},
#  {'filename': '12122.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8978543877601624},
#  {'filename': '11894.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9946909546852112},
#  {'filename': '9410.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999613761901855},
#  {'filename': '3659.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9911571741104126},
#  {'filename': '9429.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8348257541656494},
#  {'filename': '11140.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9407914280891418},
#  {'filename': '5176.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9939664602279663},
#  {'filename': '11497.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9205266237258911},
#  {'filename': '4362.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993059635162354},
#  {'filename': '3769.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.998906135559082},
#  {'filename': '10200.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9633104801177979},
#  {'filename': '1627.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996107220649719},
#  {'filename': '6549.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997860789299011},
#  {'filename': '9193.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9958744645118713},
#  {'filename': '11186.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9452356100082397},
#  {'filename': '1547.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996002316474915},
#  {'filename': '5933.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9935209155082703},
#  {'filename': '680.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9728674292564392},
#  {'filename': '3582.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8962362408638},
#  {'filename': '6019.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9459658861160278},
#  {'filename': '7875.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998712539672852},
#  {'filename': '11831.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9802518486976624},
#  {'filename': '3400.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9747864007949829},
#  {'filename': '2651.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9598594307899475},
#  {'filename': '11913.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997647404670715},
#  {'filename': '8589.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9918559789657593},
#  {'filename': '4270.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9982900023460388},
#  {'filename': '1098.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9498183131217957},
#  {'filename': '148.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9936424493789673},
#  {'filename': '1904.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9973810315132141},
#  {'filename': '1981.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997146725654602},
#  {'filename': '2025.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9219908118247986},
#  {'filename': '4051.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999655485153198},
#  {'filename': '9549.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9988546371459961},
#  {'filename': '8775.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9994269609451294},
#  {'filename': '12464.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999915361404419},
#  {'filename': '8380.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9990280866622925},
#  {'filename': '10317.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9911003708839417},
#  {'filename': '2863.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9969133138656616},
#  {'filename': '3113.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9102414846420288},
#  {'filename': '1037.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9894117712974548},
#  {'filename': '3961.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9968605041503906},
#  {'filename': '9225.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9948447942733765},
#  {'filename': '11413.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9800488948822021},
#  {'filename': '10287.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9924720525741577},
#  {'filename': '8463.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9861710667610168},
#  {'filename': '3293.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9863752722740173},
#  {'filename': '9202.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999994039535522},
#  {'filename': '11952.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999997615814209},
#  {'filename': '8071.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.982264518737793},
#  {'filename': '9670.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999524712562561},
#  {'filename': '1836.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9831581115722656},
#  {'filename': '6846.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998612403869629},
#  {'filename': '2057.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9443833827972412},
#  {'filename': '10145.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999704360961914},
#  {'filename': '12103.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989175796508789},
#  {'filename': '2373.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999998807907104},
#  {'filename': '2348.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996156692504883},
#  {'filename': '5640.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9991846680641174},
#  {'filename': '5806.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9844845533370972},
#  {'filename': '6153.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999875545501709},
#  {'filename': '10095.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997519850730896},
#  {'filename': '5843.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999529242515564},
#  {'filename': '10525.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998494386672974},
#  {'filename': '5980.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9987230896949768},
#  {'filename': '9867.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997548460960388},
#  {'filename': '10904.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9912139773368835},
#  {'filename': '1993.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9748048186302185},
#  {'filename': '4914.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9757204055786133},
#  {'filename': '7022.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999808132648468},
#  {'filename': '12291.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998732805252075},
#  {'filename': '2829.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9985392093658447},
#  {'filename': '3193.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993650317192078},
#  {'filename': '4853.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9984315037727356},
#  {'filename': '10284.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9974542260169983},
#  {'filename': '749.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993599057197571},
#  {'filename': '7501.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9854844212532043},
#  {'filename': '1816.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997878670692444},
#  {'filename': '6681.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9976366758346558},
#  {'filename': '1414.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998437166213989},
#  {'filename': '10708.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995672106742859},
#  {'filename': '9688.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999235987663269},
#  {'filename': '6040.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9963979721069336},
#  {'filename': '3817.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995545744895935},
#  {'filename': '3466.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998422861099243},
#  {'filename': '9756.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.999993085861206},
#  {'filename': '1333.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.7196449637413025},
#  {'filename': '10157.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8624297380447388},
#  {'filename': '6713.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999473094940186},
#  {'filename': '2093.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999127388000488},
#  {'filename': '6938.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999748468399048},
#  {'filename': '6717.jpg',
#   'true_label': 1,
#   'predicted_label': 0,
#   'max_prob': 0.7686867713928223},
#  {'filename': '7097.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9989756345748901},
#  {'filename': '10112.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9922391176223755},
#  {'filename': '8877.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995836615562439},
#  {'filename': '7433.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9141480326652527},
#  {'filename': '1309.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9981873631477356},
#  {'filename': '4104.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9873853921890259},
#  {'filename': '10252.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.7513277530670166},
#  {'filename': '7608.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9917142987251282},
#  {'filename': '8108.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996459484100342},
#  {'filename': '8101.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.6322022676467896},
#  {'filename': '3144.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9972731471061707},
#  {'filename': '73.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9995359182357788},
#  {'filename': '3378.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9681311845779419},
#  {'filename': '825.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9961357116699219},
#  {'filename': '9226.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9730238318443298},
#  {'filename': '5646.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993440508842468},
#  {'filename': '257.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9999828338623047},
#  {'filename': '8050.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998825788497925},
#  {'filename': '7457.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.5195688605308533},
#  {'filename': '1790.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9979162812232971},
#  {'filename': '23.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8634394407272339},
#  {'filename': '5340.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.973760724067688},
#  {'filename': '11592.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.981953501701355},
#  {'filename': '7669.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997848868370056},
#  {'filename': '2847.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998145699501038},
#  {'filename': '5537.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9993258714675903},
#  {'filename': '7092.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9998670816421509},
#  {'filename': '8107.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8238328695297241},
#  {'filename': '4959.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9996559619903564},
#  {'filename': '1016.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9651191234588623},
#  {'filename': '3219.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.9997990727424622},
#  {'filename': '10992.jpg',
#   'true_label': 1,
#   'predicted_label': 1,
#   'max_prob': 0.8818045258522034},
#  ...]
